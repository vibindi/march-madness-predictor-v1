# %% [markdown]
# # Data Collection

# %%
import requests
import os
from bs4 import BeautifulSoup as bs
from bs4 import Comment

# %%
import pandas as pd
import numpy as np

# %%
import re

# %% [markdown]
# ## Get HTML Data of Tournament

# %%
url_tournament = "https://www.sports-reference.com/cbb/postseason/men/{}-ncaa.html"

url = url_tournament.format(2024)

data = requests.get(url)

with open(f"{2024}.html", "w+") as f:
    f.write(data.text)

# %% [markdown]
# ## Parse HTML Data of Tournament

# %%
def parse_tournament_html(year):
    with open(f"{year}.html") as f:
        page = f.read()
    soup = bs(page, 'html.parser')
    brackets = soup.find("div", {"id": "brackets"})
    if brackets:
        children = []
        for child in brackets.findChildren():
            child_id = child.get("id")
            if not child_id == None and not child_id == "bracket":
                children.append(child_id)
        return year, children, brackets

# %%
def parse_brackets(year):
    data = []
    
    brackets = parse_tournament_html(year)
    
    for b in brackets[1]:
        rounds = brackets[2].find("div", {"id": b}).find_all("div", {"class": "round"})
        games = rounds[0].find_all("div", recursive=False)
        for g in games:
            g_items = g.find_all(recursive=False)

            team_one_wins = False

            t1 = g_items[0]
            i1 = t1.find_all(recursive=False)

            t2 = g_items[1]
            i2 = t2.find_all(recursive=False)


            if t1.get("class") == ["winner"]:
                team_one_wins = True


            data.append({
                'year': year,
                'bracket': b.title(),
                'round': 'First Round',
                'location': g_items[-1].getText().replace('at', '').strip(),
                'team_one_rank': i1[0].getText(),
                'team_one': i1[1].getText(),
                'team_two_rank': i2[0].getText(),
                'team_two': i2[1].getText()
            })
    return data

# %%
bracket_data = parse_brackets(2024)

# %%
bracket_data
# Out:
# [{'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Brooklyn, NY',
#   'team_one_rank': '1',
#   'team_one': 'Connecticut',
#   'team_two_rank': '16',
#   'team_two': 'Stetson'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Brooklyn, NY',
#   'team_one_rank': '8',
#   'team_one': 'Florida Atlantic',
#   'team_two_rank': '9',
#   'team_two': 'Northwestern'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Spokane, WA',
#   'team_one_rank': '5',
#   'team_one': 'San Diego State',
#   'team_two_rank': '12',
#   'team_two': 'UAB'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Spokane, WA',
#   'team_one_rank': '4',
#   'team_one': 'Auburn',
#   'team_two_rank': '13',
#   'team_two': 'Yale'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Omaha, NE',
#   'team_one_rank': '6',
#   'team_one': 'Brigham Young',
#   'team_two_rank': '11',
#   'team_two': 'Duquesne'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Omaha, NE',
#   'team_one_rank': '3',
#   'team_one': 'Illinois',
#   'team_two_rank': '14',
#   'team_two': 'Morehead State'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Omaha, NE',
#   'team_one_rank': '7',
#   'team_one': 'Washington State',
#   'team_two_rank': '10',
#   'team_two': 'Drake'},
#  {'year': 2024,
#   'bracket': 'East',
#   'round': 'First Round',
#   'location': 'Omaha, NE',
#   'team_one_rank': '2',
#   'team_one': 'Iowa State',
#   'team_two_rank': '15',
#   'team_two': 'South Dakota State'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Indianapolis, IN',
#   'team_one_rank': '1',
#   'team_one': 'Purdue',
#   'team_two_rank': '16',
#   'team_two': 'Grambling'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Indianapolis, IN',
#   'team_one_rank': '8',
#   'team_one': 'Utah State',
#   'team_two_rank': '9',
#   'team_two': 'TCU'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Salt Lake City, UT',
#   'team_one_rank': '5',
#   'team_one': 'Gonzaga',
#   'team_two_rank': '12',
#   'team_two': 'McNeese State'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Salt Lake City, UT',
#   'team_one_rank': '4',
#   'team_one': 'Kansas',
#   'team_two_rank': '13',
#   'team_two': 'Samford'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Pittsburgh, PA',
#   'team_one_rank': '6',
#   'team_one': 'South Carolina',
#   'team_two_rank': '11',
#   'team_two': 'Oregon'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Pittsburgh, PA',
#   'team_one_rank': '3',
#   'team_one': 'Creighton',
#   'team_two_rank': '14',
#   'team_two': 'Akron'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Charlotte, NC',
#   'team_one_rank': '7',
#   'team_one': 'Texas',
#   'team_two_rank': '10',
#   'team_two': 'Colorado State'},
#  {'year': 2024,
#   'bracket': 'Midwest',
#   'round': 'First Round',
#   'location': 'Charlotte, NC',
#   'team_one_rank': '2',
#   'team_one': 'Tennessee',
#   'team_two_rank': '15',
#   'team_two': "Saint Peter's"},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Memphis, TN',
#   'team_one_rank': '1',
#   'team_one': 'Houston',
#   'team_two_rank': '16',
#   'team_two': 'Longwood'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Memphis, TN',
#   'team_one_rank': '8',
#   'team_one': 'Nebraska',
#   'team_two_rank': '9',
#   'team_two': 'Texas A&M'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Brooklyn, NY',
#   'team_one_rank': '5',
#   'team_one': 'Wisconsin',
#   'team_two_rank': '12',
#   'team_two': 'James Madison'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Brooklyn, NY',
#   'team_one_rank': '4',
#   'team_one': 'Duke',
#   'team_two_rank': '13',
#   'team_two': 'Vermont'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Pittsburgh, PA',
#   'team_one_rank': '6',
#   'team_one': 'Texas Tech',
#   'team_two_rank': '11',
#   'team_two': 'NC State'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Pittsburgh, PA',
#   'team_one_rank': '3',
#   'team_one': 'Kentucky',
#   'team_two_rank': '14',
#   'team_two': 'Oakland'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Indianapolis, IN',
#   'team_one_rank': '7',
#   'team_one': 'Florida',
#   'team_two_rank': '10',
#   'team_two': 'Boise State'},
#  {'year': 2024,
#   'bracket': 'South',
#   'round': 'First Round',
#   'location': 'Indianapolis, IN',
#   'team_one_rank': '2',
#   'team_one': 'Marquette',
#   'team_two_rank': '15',
#   'team_two': 'Western Kentucky'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Charlotte, NC',
#   'team_one_rank': '1',
#   'team_one': 'North Carolina',
#   'team_two_rank': '16',
#   'team_two': 'Wagner'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Charlotte, NC',
#   'team_one_rank': '8',
#   'team_one': 'Mississippi State',
#   'team_two_rank': '9',
#   'team_two': 'Michigan State'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Spokane, WA',
#   'team_one_rank': '5',
#   'team_one': "Saint Mary's (CA)",
#   'team_two_rank': '12',
#   'team_two': 'Grand Canyon'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Spokane, WA',
#   'team_one_rank': '4',
#   'team_one': 'Alabama',
#   'team_two_rank': '13',
#   'team_two': 'College of Charleston'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Memphis, TN',
#   'team_one_rank': '6',
#   'team_one': 'Clemson',
#   'team_two_rank': '11',
#   'team_two': 'New Mexico'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Memphis, TN',
#   'team_one_rank': '3',
#   'team_one': 'Baylor',
#   'team_two_rank': '14',
#   'team_two': 'Colgate'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Salt Lake City, UT',
#   'team_one_rank': '7',
#   'team_one': 'Dayton',
#   'team_two_rank': '10',
#   'team_two': 'Nevada'},
#  {'year': 2024,
#   'bracket': 'West',
#   'round': 'First Round',
#   'location': 'Salt Lake City, UT',
#   'team_one_rank': '2',
#   'team_one': 'Arizona',
#   'team_two_rank': '15',
#   'team_two': 'Long Beach State'}]

# %%
df = pd.DataFrame(bracket_data)
df
# Out:
#     year  bracket        round            location team_one_rank  \
# 0   2024     East  First Round        Brooklyn, NY             1
# 1   2024     East  First Round        Brooklyn, NY             8
# 2   2024     East  First Round         Spokane, WA             5
# 3   2024     East  First Round         Spokane, WA             4
# 4   2024     East  First Round           Omaha, NE             6
# 5   2024     East  First Round           Omaha, NE             3
# 6   2024     East  First Round           Omaha, NE             7
# 7   2024     East  First Round           Omaha, NE             2
# 8   2024  Midwest  First Round    Indianapolis, IN             1
# 9   2024  Midwest  First Round    Indianapolis, IN             8
# 10  2024  Midwest  First Round  Salt Lake City, UT             5
# 11  2024  Midwest  First Round  Salt Lake City, UT             4
# 12  2024  Midwest  First Round      Pittsburgh, PA             6
# 13  2024  Midwest  First Round      Pittsburgh, PA             3
# 14  2024  Midwest  First Round       Charlotte, NC             7
# 15  2024  Midwest  First Round       Charlotte, NC             2
# 16  2024    South  First Round         Memphis, TN             1
# 17  2024    South  First Round         Memphis, TN             8
# 18  2024    South  First Round        Brooklyn, NY             5
# 19  2024    South  First Round        Brooklyn, NY             4
# 20  2024    South  First Round      Pittsburgh, PA             6
# 21  2024    South  First Round      Pittsburgh, PA             3
# 22  2024    South  First Round    Indianapolis, IN             7
# 23  2024    South  First Round    Indianapolis, IN             2
# 24  2024     West  First Round       Charlotte, NC             1
# 25  2024     West  First Round       Charlotte, NC             8
# 26  2024     West  First Round         Spokane, WA             5
# 27  2024     West  First Round         Spokane, WA             4
# 28  2024     West  First Round         Memphis, TN             6
# 29  2024     West  First Round         Memphis, TN             3
# 30  2024     West  First Round  Salt Lake City, UT             7
# 31  2024     West  First Round  Salt Lake City, UT             2
#
#              team_one team_two_rank               team_two
# 0         Connecticut            16                Stetson
# 1    Florida Atlantic             9           Northwestern
# 2     San Diego State            12                    UAB
# 3              Auburn            13                   Yale
# 4       Brigham Young            11               Duquesne
# 5            Illinois            14         Morehead State
# 6    Washington State            10                  Drake
# 7          Iowa State            15     South Dakota State
# 8              Purdue            16              Grambling
# 9          Utah State             9                    TCU
# 10            Gonzaga            12          McNeese State
# 11             Kansas            13                Samford
# 12     South Carolina            11                 Oregon
# 13          Creighton            14                  Akron
# 14              Texas            10         Colorado State
# 15          Tennessee            15          Saint Peter's
# 16            Houston            16               Longwood
# 17           Nebraska             9              Texas A&M
# 18          Wisconsin            12          James Madison
# 19               Duke            13                Vermont
# 20         Texas Tech            11               NC State
# 21           Kentucky            14                Oakland
# 22            Florida            10            Boise State
# 23          Marquette            15       Western Kentucky
# 24     North Carolina            16                 Wagner
# 25  Mississippi State             9         Michigan State
# 26  Saint Mary's (CA)            12           Grand Canyon
# 27            Alabama            13  College of Charleston
# 28            Clemson            11             New Mexico
# 29             Baylor            14                Colgate
# 30             Dayton            10                 Nevada
# 31            Arizona            15       Long Beach State

# %%
df.to_csv('data/2024_tournament.csv', sep=',', index=False, encoding='utf-8')

# %% [markdown]
# ## Get HTML Data of Season Standings

# %%
url_season = "https://www.sports-reference.com/cbb/seasons/men/{}-standings.html"

url = url_season.format(2024)

data = requests.get(url)

with open(f"{2024}-season.html", "w+") as f:
    f.write(data.text)

# %% [markdown]
# ## Parse HTML Data of Season Standings

# %%
def parse_standings(year):
    data = []
    with open(f"{year}-season.html") as f:
        page = f.read()
    soup = bs(page, 'html.parser')
    conferences = soup.find("div", {"id": "content"})

    for c in conferences.find_all("div", recursive=False):
        if c.get('id') and 'all_standings' in c.get('id'):
            conf = ' '.join(c.get('id')[len('all_standings') + 1:].split('-'))
            
            for child in c.descendants:
                if isinstance(child, Comment):
                    parsed_child = bs(child.string, "html")
                    for t in parsed_child.find_all("tr")[2:]:
                        info = [h.getText() for h in t.find_all(recursive=False)]
                        
                        conference_tournament_champion = False
                        if info[21]:
                            for i in info[21].split(";"):
                                if 'Conf. Tournament Champion' in i:
                                    conference_tournament_champion = True
                        
                        
                        data.append({
                            'year': year,
                            'conference': info[2],
                            'rank': int(info[0]) if info[0] else None,
                            'team': info[1],
                            'overall_wins': int(info[3]) if info[3] else None,
                            'overall_losses': int(info[4]) if info[4] else None,
                            'overall_win_loss_percentage': float(info[5]) if info[5] else None,
                            'conference_wins': int(info[7]) if info[7] else None,
                            'conference_losses': int(info[8]) if info[8] else None,
                            'conference_win_loss_percentage': float(info[9]) if info[9] else None,
                            'own_points_per_game': float(info[11]) if info[11] else None,
                            'opp_points_per_game': float(info[12]) if info[12] else None,
                            'strength_of_schedule': float(info[14]) if info[14] else None,
                            'simple_rating_system': float(info[15]) if info[15] else None,
                            'ap_pre': int(info[17]) if info[17] else None,
                            'ap_high': int(info[18]) if info[18] else None,
                            'ap_final': int(info[19]) if info[19] else None,
                            'conference_tournament_champion': conference_tournament_champion
                        })
    return data

# %%
standings_data = []

standings_data.extend(parse_standings(2024))

df2 = pd.DataFrame(standings_data)
df2
# Out:
#      year conference  rank              team  overall_wins  overall_losses  \
# 0    2024        AAC     1     South Florida            24               7
# 1    2024        AAC     2  Florida Atlantic            25               8
# 2    2024        AAC     3         Charlotte            19              12
# 3    2024        AAC     4               UAB            23              11
# 4    2024        AAC     5           Memphis            22              10
# ..    ...        ...   ...               ...           ...             ...
# 357  2024        WCC     5         San Diego            18              15
# 358  2024        WCC     6        Pepperdine            13              20
# 359  2024        WCC     7  Loyola Marymount            12              19
# 360  2024        WCC     8          Portland            12              21
# 361  2024        WCC     9           Pacific             6              26
#
#      overall_win_loss_percentage  conference_wins  conference_losses  \
# 0                          0.774             16.0                2.0
# 1                          0.758             14.0                4.0
# 2                          0.613             13.0                5.0
# 3                          0.676             12.0                6.0
# 4                          0.688             11.0                7.0
# ..                           ...              ...                ...
# 357                        0.545              7.0                9.0
# 358                        0.394              5.0               11.0
# 359                        0.387              5.0               11.0
# 360                        0.364              5.0               11.0
# 361                        0.188              0.0               16.0
#
#      conference_win_loss_percentage  own_points_per_game  opp_points_per_game  \
# 0                             0.889                 75.8                 69.1
# 1                             0.778                 82.5                 73.3
# 2                             0.722                 68.0                 66.3
# 3                             0.667                 77.4                 75.8
# 4                             0.611                 80.5                 75.8
# ..                              ...                  ...                  ...
# 357                           0.438                 72.5                 78.1
# 358                           0.313                 72.4                 75.2
# 359                           0.313                 71.2                 71.5
# 360                           0.313                 69.8                 79.5
# 361                           0.000                 64.1                 81.4
#
#      strength_of_schedule  simple_rating_system  ap_pre  ap_high ap_final  \
# 0                    7.38                  0.60     NaN     24.0     None
# 1                   13.89                  4.61    10.0      7.0     None
# 2                    4.37                  2.70     NaN      NaN     None
# 3                    5.20                  3.62     NaN      NaN     None
# 4                    9.23                  4.48     NaN     10.0     None
# ..                    ...                   ...     ...      ...      ...
# 357                 -5.09                  0.55     NaN      NaN     None
# 358                 -1.94                  0.90     NaN      NaN     None
# 359                  0.07                  0.44     NaN      NaN     None
# 360                 -8.02                  1.72     NaN      NaN     None
# 361                -17.21                  0.06     NaN      NaN     None
#
#      conference_tournament_champion
# 0                             False
# 1                             False
# 2                             False
# 3                              True
# 4                             False
# ..                              ...
# 357                           False
# 358                           False
# 359                           False
# 360                           False
# 361                           False
#
# [362 rows x 18 columns]

# %%
df2.isna().sum()
# Out:
# year                              0
# conference                        0
# rank                              0
# team                              0
# overall_wins                      0
# overall_losses                    0
# overall_win_loss_percentage       0
# conference_wins                   0
# conference_losses                 0
# conference_win_loss_percentage    0
# own_points_per_game               0
# opp_points_per_game               0
# strength_of_schedule              0
# simple_rating_system              0
# ap_pre                            0
# ap_high                           0
# ap_final                          0
# conference_tournament_champion    0
# dtype: int64

# %%
df2[['ap_pre']] = df2[['ap_pre']].fillna(value=26.0)

# %%
df2[['ap_high']] = df2[['ap_high']].fillna(value=26.0)

# %%
df2[['ap_final']] = df2[['ap_final']].fillna(value=26.0)

# %%
df2 = df2.dropna(subset=['conference_wins'])

# %%
df2
# Out:
#      year conference  rank              team  overall_wins  overall_losses  \
# 0    2024        AAC     1     South Florida            24               7
# 1    2024        AAC     2  Florida Atlantic            25               8
# 2    2024        AAC     3         Charlotte            19              12
# 3    2024        AAC     4               UAB            23              11
# 4    2024        AAC     5           Memphis            22              10
# ..    ...        ...   ...               ...           ...             ...
# 357  2024        WCC     5         San Diego            18              15
# 358  2024        WCC     6        Pepperdine            13              20
# 359  2024        WCC     7  Loyola Marymount            12              19
# 360  2024        WCC     8          Portland            12              21
# 361  2024        WCC     9           Pacific             6              26
#
#      overall_win_loss_percentage  conference_wins  conference_losses  \
# 0                          0.774             16.0                2.0
# 1                          0.758             14.0                4.0
# 2                          0.613             13.0                5.0
# 3                          0.676             12.0                6.0
# 4                          0.688             11.0                7.0
# ..                           ...              ...                ...
# 357                        0.545              7.0                9.0
# 358                        0.394              5.0               11.0
# 359                        0.387              5.0               11.0
# 360                        0.364              5.0               11.0
# 361                        0.188              0.0               16.0
#
#      conference_win_loss_percentage  own_points_per_game  opp_points_per_game  \
# 0                             0.889                 75.8                 69.1
# 1                             0.778                 82.5                 73.3
# 2                             0.722                 68.0                 66.3
# 3                             0.667                 77.4                 75.8
# 4                             0.611                 80.5                 75.8
# ..                              ...                  ...                  ...
# 357                           0.438                 72.5                 78.1
# 358                           0.313                 72.4                 75.2
# 359                           0.313                 71.2                 71.5
# 360                           0.313                 69.8                 79.5
# 361                           0.000                 64.1                 81.4
#
#      strength_of_schedule  simple_rating_system  ap_pre  ap_high  ap_final  \
# 0                    7.38                  0.60    26.0     24.0      26.0
# 1                   13.89                  4.61    10.0      7.0      26.0
# 2                    4.37                  2.70    26.0     26.0      26.0
# 3                    5.20                  3.62    26.0     26.0      26.0
# 4                    9.23                  4.48    26.0     10.0      26.0
# ..                    ...                   ...     ...      ...       ...
# 357                 -5.09                  0.55    26.0     26.0      26.0
# 358                 -1.94                  0.90    26.0     26.0      26.0
# 359                  0.07                  0.44    26.0     26.0      26.0
# 360                 -8.02                  1.72    26.0     26.0      26.0
# 361                -17.21                  0.06    26.0     26.0      26.0
#
#      conference_tournament_champion
# 0                             False
# 1                             False
# 2                             False
# 3                              True
# 4                             False
# ..                              ...
# 357                           False
# 358                           False
# 359                           False
# 360                           False
# 361                           False
#
# [361 rows x 18 columns]

# %%
df2.to_csv('data/2024_standings.csv', sep=',', index=False, encoding='utf-8')
